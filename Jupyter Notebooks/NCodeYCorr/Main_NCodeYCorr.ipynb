# %%
# Import TensorFlow and NumPy
import tensorflow as tf
import numpy as np

# Import Sionna
try:
    import sionna as sn
except ImportError as e:
    # Install Sionna if package is not already installed
    import os
    os.system("pip install sionna")
    import sionna as sn

# For plotting
# %matplotlib inline
# also try %matplotlib widget

import matplotlib.pyplot as plt

# for performance measurements
import time

# For the implementation of the Keras models
from tensorflow import keras
from keras import Model
from NCodeYCorr import ncodencorr

Block_Length = 1024              # Block Length (k)
NUM_BITS_PER_SYMBOL = 2         # Mapping: 4QAM
CONSTELLATION_TYPE = "qam"      # Constellation/Modulation Type
DEMAPPING_METHOD = "app"        # Demapping Method: "app"
NUM_TX_ANT = 4                  # Transmit Antennas
NUM_RX_ANT = 4                  # Receive Antennas
CORRELATION_INDEX_MIN = 0.1     # Minimum Spatial Correlation
CORRELATION_INDEX_MAX = 0.9     # Maximum Spatial Correlation
CORRELATION_INDEX_POINTS = 3    # Correlation Points between Max and Min

NUM_DATA_GROUP = 3              # Number of Data Group
BATCH_SIZE = 1024               # Number of Parallelly Processed Batches
EBN0_DB_MIN = 0.0               # Minimum Eb/N0 (dB)
EBN0_DB_MAX = 25.0              # Maximum Eb/N0 (dB)
NUM_EBN0_POINTS = 5             # EBNO Points

model_ncodencorr = ncodencorr(Block_Length, 
                                NUM_BITS_PER_SYMBOL,
                                CONSTELLATION_TYPE,
                                DEMAPPING_METHOD,
                                NUM_RX_ANT,
                                NUM_TX_ANT,
                                CORRELATION_INDEX_MIN,
                                CORRELATION_INDEX_MAX,
                                CORRELATION_INDEX_POINTS)

model_ncodencorr(NUM_DATA_GROUP, BATCH_SIZE, EBN0_DB_MIN, EBN0_DB_MAX, NUM_EBN0_POINTS)
# Out:
# 2023-05-26 12:59:55.043631: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Number of GPUs available : 0
# |                                                         TX_ANT_CORRELATION: 0.1 & RX_ANT_CORRELATION: 0.1                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  1.875e-01|  1.250e-01|               4|     6.250e-02|     3.125e-02|                  1|   6.250e-02|   3.125e-02|                1|      4.093e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  1.875e-01|  1.250e-01|               4|     1.250e-01|     6.250e-02|                  2|   0.000e+00|   0.000e+00|                0|      3.151e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d7ef4ad0-318b-4503-9ebc-44bf0ce1711f">Loading BokehJS ...</span>
#     </div>
#   <div id="c91001fa-c10e-49e4-b146-a122501fcfa6" data-root-id="p1001" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.1 & RX_ANT_CORRELATION: 0.5                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  3.125e-01|  1.562e-01|               5|     1.250e-01|     6.250e-02|                  2|   6.250e-02|   3.125e-02|                1|      6.058e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  1.250e-01|  9.375e-02|               3|     1.250e-01|     9.375e-02|                  3|   1.875e-01|   1.250e-01|                4|      5.342e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ef07b5f7-e499-41be-bfb9-f3d6989c757d">Loading BokehJS ...</span>
#     </div>
#   <div id="cb1f9979-5800-453b-958a-20f1e91699e3" data-root-id="p1552" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.1 & RX_ANT_CORRELATION: 0.9                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  5.000e-01|  3.438e-01|              11|     2.500e-01|     1.250e-01|                  4|   2.500e-01|   1.250e-01|                4|      7.507e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  3.750e-01|  2.188e-01|               7|     2.500e-01|     1.562e-01|                  5|   1.875e-01|   1.250e-01|                4|      5.258e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="eb41fdcc-3a04-4513-b6e3-6d4baf9821c5">Loading BokehJS ...</span>
#     </div>
#   <div id="e5459946-59c6-4846-9da1-98879fd18c54" data-root-id="p2217" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.5 & RX_ANT_CORRELATION: 0.1                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  2.500e-01|  1.562e-01|               5|     6.250e-02|     3.125e-02|                  1|   0.000e+00|   0.000e+00|                0|      4.878e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  0.000e+00|  0.000e+00|               0|     0.000e+00|     0.000e+00|                  0|   0.000e+00|   0.000e+00|                0|      3.056e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a1d19d10-dd74-4579-9b1d-7fda6a30afbf">Loading BokehJS ...</span>
#     </div>
#   <div id="a2475a58-2221-424c-94a3-349a48a75d7b" data-root-id="p2920" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.5 & RX_ANT_CORRELATION: 0.5                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  4.375e-01|  2.188e-01|               7|     2.500e-01|     1.562e-01|                  5|   1.250e-01|   9.375e-02|                3|      4.904e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  3.125e-01|  1.562e-01|               5|     6.250e-02|     3.125e-02|                  1|   0.000e+00|   0.000e+00|                0|      3.345e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b1b35f58-b270-4629-aa24-a18668688da8">Loading BokehJS ...</span>
#     </div>
#   <div id="c546ace2-14b9-4034-a2fb-4ce1ef70ce48" data-root-id="p3661" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.5 & RX_ANT_CORRELATION: 0.9                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  3.125e-01|  2.188e-01|               7|     1.875e-01|     9.375e-02|                  3|   6.250e-02|   3.125e-02|                1|      6.566e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  2.500e-01|  1.875e-01|               6|     1.875e-01|     1.250e-01|                  4|   1.250e-01|   6.250e-02|                2|      4.394e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a2b8553b-4ea7-4a37-91d7-274c2f36abc2">Loading BokehJS ...</span>
#     </div>
#   <div id="d80b7b0d-2e94-4fdb-8ef3-32a8d78fe05e" data-root-id="p4440" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.9 & RX_ANT_CORRELATION: 0.1                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  4.375e-01|  2.812e-01|               9|     1.875e-01|     9.375e-02|                  3|   2.500e-01|   1.250e-01|                4|      6.634e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  3.750e-01|  2.188e-01|               7|     1.250e-01|     6.250e-02|                  2|   1.250e-01|   6.250e-02|                2|      4.503e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e0fff807-b5a6-48c4-9673-ce911a565fc3">Loading BokehJS ...</span>
#     </div>
#   <div id="e765e252-3e16-4242-b3ec-51411fe7fafd" data-root-id="p5257" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.9 & RX_ANT_CORRELATION: 0.5                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  5.000e-01|  2.500e-01|               8|     5.000e-01|     2.500e-01|                  8|   3.750e-01|   2.188e-01|                7|      5.739e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  6.250e-01|  5.312e-01|              17|     6.250e-02|     6.250e-02|                  2|   0.000e+00|   0.000e+00|                0|      4.308e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b9007229-a84f-4dac-b5ce-67455c8e2f90">Loading BokehJS ...</span>
#     </div>
#   <div id="ba540fb3-578b-45e9-822a-4a6e2452089f" data-root-id="p6112" style="display: contents;"></div>
# |                                                         TX_ANT_CORRELATION: 0.9 & RX_ANT_CORRELATION: 0.9                                                         |
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         0.0|  6.875e-01|  4.688e-01|              15|     2.500e-01|     1.250e-01|                  4|   3.125e-01|   1.562e-01|                5|      5.625e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |         5.0|  5.625e-01|  3.125e-01|              10|     4.375e-01|     2.188e-01|                  7|   3.750e-01|   2.188e-01|                7|      5.162e-01|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d023c8a8-f35a-4672-bff7-794155b59825">Loading BokehJS ...</span>
#     </div>
#   <div id="d94d8961-d9ba-437a-9535-a888c3d194bd" data-root-id="p7005" style="display: contents;"></div>
# (array([0., 5.]),
#  array([[0.1875, 0.1875],
#         [0.3125, 0.125 ],
#         [0.5   , 0.375 ],
#         [0.25  , 0.    ],
#         [0.4375, 0.3125],
#         [0.3125, 0.25  ],
#         [0.4375, 0.375 ],
#         [0.5   , 0.625 ],
#         [0.6875, 0.5625]]),
#  array([[0.0625, 0.125 ],
#         [0.125 , 0.125 ],
#         [0.25  , 0.25  ],
#         [0.0625, 0.    ],
#         [0.25  , 0.0625],
#         [0.1875, 0.1875],
#         [0.1875, 0.125 ],
#         [0.5   , 0.0625],
#         [0.25  , 0.4375]]),
#  array([[0.0625, 0.    ],
#         [0.0625, 0.1875],
#         [0.25  , 0.1875],
#         [0.    , 0.    ],
#         [0.125 , 0.    ],
#         [0.0625, 0.125 ],
#         [0.25  , 0.125 ],
#         [0.375 , 0.    ],
#         [0.3125, 0.375 ]]))
