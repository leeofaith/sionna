# %%
# Import TensorFlow and NumPy
import tensorflow as tf
import numpy as np

# Import Sionna
try:
    import sionna as sn
except ImportError as e:
    # Install Sionna if package is not already installed
    import os
    os.system("pip install sionna")
    import sionna as sn

# For plotting
# %matplotlib inline
# also try %matplotlib widget

import matplotlib.pyplot as plt

# for performance measurements
import time

# For the implementation of the Keras models
from tensorflow import keras
from keras import Model
from NCodeNCorr import ncodencorr

Block_Length = 128         # Block Length (k)
NUM_BITS_PER_SYMBOL = 2    # Mapping: 4QAM
CONSTELLATION_TYPE = "qam" #
DEMAPPING_METHOD = "app"   # Demapping Method: "app"
NUM_TX_ANT = 4             # Transmit Antennas
NUM_RX_ANT = 4             # Receive Antennas

NUM_DATA_GROUP = 3         # Number of Data Group
BATCH_SIZE = 64            # Number of Parallelly Processed Batches
EBN0_DB_MIN = 25.0          # Minimum Eb/N0 (dB)
EBN0_DB_MAX = 25.0         # Maximum Eb/N0 (dB)
NUM_EBN0_POINTS = 1        # EBNO Points

model_ncodencorr = ncodencorr(Block_Length, 
                              NUM_BITS_PER_SYMBOL,
                              CONSTELLATION_TYPE,
                              DEMAPPING_METHOD,
                              NUM_RX_ANT,
                              NUM_TX_ANT)

model_ncodencorr(NUM_DATA_GROUP,
                 BATCH_SIZE,
                 EBN0_DB_MIN,
                 EBN0_DB_MAX,
                 NUM_EBN0_POINTS)
# Out:
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |        25.0|  1.343e-03|  7.629e-04|              25|     5.493e-04|     2.747e-04|                  9|   1.465e-03|   7.629e-04|               25|      2.420e+02|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# |                                                                            Data Group 2                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |        25.0|  9.766e-04|  5.798e-04|              19|     3.662e-04|     1.831e-04|                  6|   1.587e-03|   8.545e-04|               28|      3.020e+02|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# |                                                                            Data Group 3                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |        25.0|  1.465e-03|  7.935e-04|              26|     4.883e-04|     3.052e-04|                 10|   1.465e-03|   7.629e-04|               25|      3.053e+02|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dbcd3898-eb0d-49ff-8275-980007296d65">Loading BokehJS ...</span>
#     </div>
#   <div id="d323b270-e208-493e-b9d3-e7474b7e6577" data-root-id="p1752" style="display: contents;"></div>
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b7e091a2-ffae-4db6-9937-252378a77b9b">Loading BokehJS ...</span>
#     </div>
#   <div id="e150a25e-5109-4e6c-95bf-d5c03e912e54" data-root-id="p2185" style="display: contents;"></div>
# (array([25.]), array([0.00126139]), array([0.00046794]), array([0.00150553]))
