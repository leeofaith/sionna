# %%
# Import TensorFlow and NumPy
import tensorflow as tf
import numpy as np

# Import Sionna
try:
    import sionna as sn
except ImportError as e:
    # Install Sionna if package is not already installed
    import os
    os.system("pip install sionna")
    import sionna as sn

# For plotting
# %matplotlib inline
# also try %matplotlib widget

import matplotlib.pyplot as plt

# for performance measurements
import time

# For the implementation of the Keras models
from tensorflow import keras
from keras import Model
from UncodedSystemFlatFading import UncodedSystemFlatFading

Block_Length = 12         # Block Length (k)
NUM_BITS_PER_SYMBOL = 4    # Mapping: 16QAM
CONSTELLATION_TYPE = "qam" #
DEMAPPING_METHOD = "app"   # Demapping Method: "app"
NUM_TX_ANT = 4             # Transmit Antennas
NUM_RX_ANT = 16             # Receive Antennas

NUM_DATA_GROUP = 1        # Number of Data Group
BATCH_SIZE = 2048            # Number of Parallelly Processed Batches
EBN0_DB_MIN = 10.0        # Minimum Eb/N0 (dB)
EBN0_DB_MAX = 20.0         # Maximum Eb/N0 (dB)
NUM_EBN0_POINTS = 2       # EBNO Points

model_uncoded_ff = UncodedSystemFlatFading(Block_Length, 
                                           NUM_BITS_PER_SYMBOL,
                                           CONSTELLATION_TYPE,
                                           DEMAPPING_METHOD,
                                           NUM_RX_ANT,
                                           NUM_TX_ANT)

model_uncoded_ff(NUM_DATA_GROUP, BATCH_SIZE, EBN0_DB_MIN, EBN0_DB_MAX, NUM_EBN0_POINTS)
# Out:
# |                                                                            Data Group 1                                                                           |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  EBN0[DB]  |  SER(ZF)  |  BER(ZF)  | Bit Errors(ZF) |  SER(LMMSE)  |  BER(LMMSE)  | Bit Errors(LMMSE) |  SER(DIP)  |  BER(DIP)  | Bit Errors(DIP) | Time Spent(s) |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |        10.0|  0.000e+00|  0.000e+00|               0|     0.000e+00|     0.000e+00|                  0|   4.069e-05|   1.017e-05|                1|      5.544e+02|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |        20.0|  0.000e+00|  0.000e+00|               0|     0.000e+00|     0.000e+00|                  0|   0.000e+00|   0.000e+00|                0|      5.518e+02|
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# Done
# (array([10., 20.]),
#  array([0., 0.]),
#  array([0., 0.]),
#  array([4.06901042e-05, 0.00000000e+00]))
